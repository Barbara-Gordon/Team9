# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
import gmaps
from pprint import pprint
from us import states
from scipy import stats


gmaps_api = 'AIzaSyATqobtGQXrLENTJ70_23O5q95oUSCuGT0'

incentiveDF = pd.read_csv('Datasets\IncentiveData',index_col = 0)

#Drop rows that have no dates
incentiveDF = incentiveDF.dropna(thresh = 4)
incentiveDF = incentiveDF.loc[incentiveDF['state_name']!='US',:]
incentiveDF.head(100)
# Out:
#                                                  title  \
# 4    Alternative Fuel Vehicle (AFV) and Energy Effi...
# 5    Alternative Fuel Vehicle Emissions Test Exemption
# 6    Reduced Alternative Fuel Vehicle (AFV) License...
# 7    Plug-In Electric Vehicle (PEV) Charging Rate R...
# 8    Alternative Fuel Vehicle (AFV) Weight Limit Ex...
# 11         High Occupancy Vehicle (HOV) Lane Exemption
# 12                    Alternative Fuel and Vehicle Tax
# 15   High Occupancy Vehicle (HOV) and High Occupanc...
# 17          Alternative Fuel and Idle Reduction Grants
# 18             Clean Vehicle and Infrastructure Grants
# 19               Pollution Control Equipment Exemption
# 21                 Alternative Fuel Vehicle Conversion
# 22   High Occupancy Vehicle (HOV) and High Occupanc...
# 24   Alternative Fuel Vehicle (AFV) Emissions Inspe...
# 27   Alternative Fuel Vehicle (AFV) Emissions Inspe...
# 28                Alternative Fuel Vehicle (AFV) Decal
# 30         High Occupancy Vehicle (HOV) Lane Exemption
# 32               Alternative Fuel Vehicle (AFV) Rebate
# 37   Plug-In Electric Vehicle (PEV) Title Excise Ta...
# 42         High Occupancy Vehicle (HOV) Lane Exemption
# 44   Plug-In Electric Vehicle (PEV) Charging Infras...
# 46         High Occupancy Vehicle (HOV) Lane Exemption
# 47             Alternative Fuel and Vehicle Incentives
# 48         High Occupancy Vehicle (HOV) Lane Exemption
# 51                  Clean Vehicle Replacement Vouchers
# 52   Plug-In Electric Vehicle (PEV) and Electric Ve...
# 53                       Vehicle-to-Grid Energy Credit
# 54   Alternative Fuel Vehicle (AFV) and Fueling Inf...
# 56   Plug-In Hybrid and Zero Emission Light-Duty Ve...
# 57           Plug-In Electric Vehicle (PEV) Tax Credit
# ..                                                 ...
# 109    Electric Vehicle Supply Equipment (EVSE) Grants
# 110                           Clean School Bus Program
# 111  Plug-In Electric Vehicle (PEV) Charging Rate I...
# 112  Establishment of a Zero Emission Medium- and H...
# 113                       Low-Speed Vehicle Definition
# 115        Plug-in Electric Vehicle (PEV) Rebate - JEA
# 116  Electric Vehicle Supply Equipment (EVSE) Rebat...
# 117  Plug-In Electric Vehicle (PEV) Charging Electr...
# 118  Residential Electric Vehicle Supply Equipment ...
# 119     Reduced Registration Fee for Electric Vehicles
# 120  Plug-In Electric Vehicle (PEV) and Electric Ve...
# 122                      Clean Truck Port Requirements
# 123  Plug-In Electric Vehicle (PEV) Charging Rate a...
# 124    Electric Vehicle Emissions Inspection Exemption
# 125  Alternative Fuel Vehicle (AFV) Emissions Inspe...
# 126    Electric Vehicle Emissions Inspection Exemption
# 127    Electric Vehicle Emissions Inspection Exemption
# 128  All-Electric Vehicle (EV) Emissions Inspection...
# 129    Electric Vehicle Emissions Inspection Exemption
# 130    Electric Vehicle Emissions Inspection Exemption
# 131           Plug-in Electric Vehicle (PEV) Decal Fee
# 132                          Alternative Fuel Tax Rate
# 133          Plug-In Electric Vehicle (PEV) Annual Fee
# 134  Electric Vehicle Supply Equipment Regulation E...
# 135                 Plug-In Electric Vehicle (PEV) Fee
# 136  Plug-In Electric Vehicle (PEV) Voluntary Time ...
# 137  Hydrogen and Plug-In Electric Vehicle (PEV) Re...
# 138  Voluntary Vehicle Retirement Incentives - San ...
# 139  Electric Vehicle Supply Equipment (EVSE) Loan ...
# 140  Plug-In Electric Vehicle (PEV) Toll Discount P...
#
#                  incentive_type state_name          enacted_date  \
# 4              State Incentives         AZ                   NaN
# 5              State Incentives         AZ                   NaN
# 6              State Incentives         AZ                   NaN
# 7    Utility/Private Incentives         CA                   NaN
# 8              State Incentives         CO                   NaN
# 11             State Incentives         VA                   NaN
# 12         Laws and Regulations         VA  2013-04-03T00:00:00Z
# 15             State Incentives         GA                   NaN
# 17             State Incentives         NC                   NaN
# 18             State Incentives         TX                   NaN
# 19             State Incentives         OR  2001-01-01T00:00:00Z
# 21         Laws and Regulations         OH  1993-09-27T00:00:00Z
# 22             State Incentives         CA  2006-09-29T00:00:00Z
# 24             State Incentives         MI  1995-05-24T00:00:00Z
# 27             State Incentives         MO                   NaN
# 28         Laws and Regulations         MO  1998-07-10T00:00:00Z
# 30             State Incentives         FL                   NaN
# 32             State Incentives         PA                   NaN
# 37             State Incentives         DC                   NaN
# 42             State Incentives         NJ  2006-04-27T00:00:00Z
# 44         Laws and Regulations         WA  2007-05-07T00:00:00Z
# 46             State Incentives         NY  2006-03-01T00:00:00Z
# 47             State Incentives         CA  2007-10-14T00:00:00Z
# 48             State Incentives         TN  2008-06-20T00:00:00Z
# 51             State Incentives         TX  2001-09-01T00:00:00Z
# 52             State Incentives         CO  2009-06-04T00:00:00Z
# 53             State Incentives         DE  2009-09-21T00:00:00Z
# 54             State Incentives         LA  2009-07-09T00:00:00Z
# 56             State Incentives         CA  2010-03-15T00:00:00Z
# 57             State Incentives         MD  2010-05-20T00:00:00Z
# ..                          ...        ...                   ...
# 109            State Incentives         CT  2014-07-15T00:00:00Z
# 110            State Incentives         TX                   NaN
# 111  Utility/Private Incentives         MN                   NaN
# 112        Laws and Regulations         CA  2014-09-21T00:00:00Z
# 113        Laws and Regulations         PA  2014-10-22T00:00:00Z
# 115  Utility/Private Incentives         FL                   NaN
# 116  Utility/Private Incentives         GA                   NaN
# 117        Laws and Regulations         CA  2014-08-19T00:00:00Z
# 118            State Incentives         CA  2014-09-26T00:00:00Z
# 119            State Incentives         CT  2013-01-01T00:00:00Z
# 120            State Incentives         MA                   NaN
# 122        Laws and Regulations         NJ                   NaN
# 123  Utility/Private Incentives         MI                   NaN
# 124            State Incentives         RI  1993-08-26T00:00:00Z
# 125            State Incentives         OH  1996-08-15T00:00:00Z
# 126            State Incentives         CO  2012-01-12T00:00:00Z
# 127            State Incentives         CT                   NaN
# 128            State Incentives         IL                   NaN
# 129            State Incentives         MA  1999-01-01T00:00:00Z
# 130            State Incentives         NY  2011-01-01T00:00:00Z
# 131        Laws and Regulations         WY  2015-02-25T00:00:00Z
# 132        Laws and Regulations         WY  2015-02-25T00:00:00Z
# 133        Laws and Regulations         GA  2015-05-04T00:00:00Z
# 134        Laws and Regulations         ID  2015-04-02T00:00:00Z
# 135        Laws and Regulations         ID  2015-04-21T00:00:00Z
# 136  Utility/Private Incentives         NY                   NaN
# 137            State Incentives         CT                   NaN
# 138            State Incentives         CA  2015-04-09T00:00:00Z
# 139            State Incentives         CA  2015-04-29T00:00:00Z
# 140            State Incentives         NJ                   NaN
#
#              amended_date significant_update_date
# 4    2009-07-13T00:00:00Z               7/29/2014
# 5                     NaN               5/13/2015
# 6    2018-04-25T00:00:00Z                7/6/2018
# 7                     NaN              11/14/2018
# 8                     NaN               7/12/2016
# 11   2012-04-18T00:00:00Z               9/10/2015
# 12   2014-02-27T00:00:00Z                     NaN
# 15   2015-05-04T00:00:00Z                5/5/2015
# 17                    NaN               9/12/2016
# 18                    NaN               6/18/2018
# 19                    NaN                     NaN
# 21                    NaN                     NaN
# 22   2018-09-13T00:00:00Z              11/12/2018
# 24                    NaN                     NaN
# 27   2011-05-05T00:00:00Z                     NaN
# 28   2017-06-28T00:00:00Z               7/11/2017
# 30   2010-06-04T00:00:00Z                     NaN
# 32   2008-07-10T00:00:00Z                9/8/2018
# 37   2019-01-18T00:00:00Z                2/8/2019
# 42   2017-09-18T00:00:00Z               12/5/2017
# 44   2015-05-01T00:00:00Z               6/12/2015
# 46                    NaN                     NaN
# 47   2012-10-05T00:00:00Z                     NaN
# 48                    NaN                     NaN
# 51   2011-06-17T00:00:00Z                     NaN
# 52   2014-04-11T00:00:00Z               7/11/2018
# 53                    NaN                     NaN
# 54   2013-04-30T00:00:00Z               9/11/2017
# 56   2018-09-13T00:00:00Z              11/12/2018
# 57   2017-05-04T00:00:00Z               5/11/2017
# ..                    ...                     ...
# 109                   NaN                9/4/2015
# 110  2017-06-12T00:00:00Z               8/10/2017
# 111                   NaN                8/4/2016
# 112  2018-09-22T00:00:00Z              11/13/2018
# 113                   NaN               11/6/2014
# 115                   NaN              12/18/2014
# 116                   NaN               4/10/2017
# 117                   NaN              12/18/2014
# 118                   NaN              12/19/2014
# 119                   NaN                     NaN
# 120                   NaN               2/11/2019
# 122                   NaN              12/12/2017
# 123                   NaN              11/22/2016
# 124                   NaN                     NaN
# 125                   NaN                     NaN
# 126                   NaN                     NaN
# 127  1993-07-01T00:00:00Z                     NaN
# 128  2012-01-01T00:00:00Z                     NaN
# 129                   NaN                     NaN
# 130                   NaN                     NaN
# 131  2016-03-02T00:00:00Z                3/6/2019
# 132                   NaN               4/15/2015
# 133                   NaN                5/5/2015
# 134                   NaN               5/11/2015
# 135  2017-02-28T00:00:00Z               4/10/2017
# 136                   NaN               6/12/2015
# 137                   NaN               9/11/2017
# 138                   NaN               6/12/2015
# 139                   NaN               6/12/2015
# 140                   NaN               6/18/2015
#
# [100 rows x 6 columns]

# %%
# Clean formatting of dates.
en_Date = []
for n in incentiveDF['enacted_date']:
    if isinstance(n, str) == True:
        t = n[:-16]
        en_Date.append(int(t))
    else:
        en_Date.append(2222) 

am_Date = []
for n in incentiveDF['amended_date']:
    if isinstance(n, str) == True:
        t = n[:-16]
        am_Date.append(int(t))
    else:
        am_Date.append(2222)

sig_Date = []
for n in incentiveDF['significant_update_date']:
    if isinstance(n, str) == True:
        t = n[(len(n)-4):]
        sig_Date.append(int(t))
    else:
        sig_Date.append(2222)

# %%
Date = []
for d in range(len(sig_Date)):
    if sig_Date[d] < am_Date[d] and en_Date[d]:
        Date.append(sig_Date[d])
    elif am_Date[d] < en_Date[d]:
        Date.append(am_Date[d])
    else:
        Date.append(en_Date[d])

# %%
incentive_DF = pd.DataFrame({'Title':incentiveDF['title'],'Incentive Type':incentiveDF['incentive_type'],'State or Federal':incentiveDF['state_name'],'Date':Date})

incentive_DF.head()
# Out:
#                                                Title  \
# 4  Alternative Fuel Vehicle (AFV) and Energy Effi...
# 5  Alternative Fuel Vehicle Emissions Test Exemption
# 6  Reduced Alternative Fuel Vehicle (AFV) License...
# 7  Plug-In Electric Vehicle (PEV) Charging Rate R...
# 8  Alternative Fuel Vehicle (AFV) Weight Limit Ex...
#
#                Incentive Type State or Federal  Date
# 4            State Incentives               AZ  2009
# 5            State Incentives               AZ  2015
# 6            State Incentives               AZ  2018
# 7  Utility/Private Incentives               CA  2018
# 8            State Incentives               CO  2016

# %%
incentive_GBType = incentive_DF.groupby(['Incentive Type']).aggregate({'Date':'count'})
incentive_GBState = incentive_DF.groupby(['State or Federal','Incentive Type']).aggregate({'Date':'count'})

# %%
fig = incentive_GBType.plot(kind = 'bar')

# %%
fig2 = incentive_GBState.unstack().plot(kind = 'bar',figsize = (50,20),fontsize = 30,rot = 30,stacked = True)
fig2.set_xlabel('State', fontsize = 50)
fig2.set_ylabel('Number of Incentives',fontsize = 50)
fig2.set_title('Total Incentives by State',fontsize = 50)
fig2.legend(('Laws and Regulations','State Incentives','Utilizy/Private Incentive'),fontsize = 30)

# %%
fig2 = fig2.get_figure()
fig2.savefig('Plots and Maps\Total Incentives by State')

# %%
stations= pd.read_csv('Datasets\Stationstomergewithincentives.csv')

stations = stations.rename(columns = {'Date':'Stations'})
incentive_DF = incentive_DF.rename(columns = {'State or Federal':'State'})
incentives = incentive_DF.groupby(['State']).aggregate({'Date':'count'})
stations.head()
# Out:
#   State  Stations
# 0    AK        15
# 1    AL       142
# 2    AR        64
# 3    AZ       146
# 4    CA      2118

# %%
incentives.head()
incentives.describe()
# Out:
#             Date
# count  43.000000
# mean    4.860465
# std     4.852988
# min     1.000000
# 25%     2.000000
# 50%     4.000000
# 75%     6.500000
# max    31.000000

# %%
merged_data = stations.merge(incentives, how = 'outer', on = 'State' )
merged_data = merged_data.fillna(0)
merged_data = merged_data.loc[merged_data['State']!='DC',:]
merged_data = merged_data.rename(columns = {'Date':'Incentives'})
merged_data['Stations By 10%'] = merged_data['Stations']*0.1
merged_data.head()
# Out:
#   State  Stations  Incentives  Stations By 10%
# 0    AK        15         0.0              1.5
# 1    AL       142         0.0             14.2
# 2    AR        64         1.0              6.4
# 3    AZ       146         6.0             14.6
# 4    CA      2118        31.0            211.8

# %%
figdata = merged_data.groupby(['State']).aggregate({'Incentives': 'sum','Stations By 10%':'sum'})
fig3 = figdata.plot(kind = 'bar', ylim = (0,50),figsize = (50,20),fontsize = 30,rot = 30)
fig3.legend(('Incentives','Charging Stations'),fontsize = 30,loc = 'best')
fig3.set_xlabel('State',fontsize = 30)
fig3.set_ylabel('Number of Stations and Incentives\n (Station Data reduced by 10% for visualization purposes)',fontsize = 30)
fig3.set_title('Total Number of Incentives vs Number of Electric Charging Stations per State',fontsize = 30)
# Out:
# Text(0.5,1,'Total Number of Incentives vs Number of Electric Charging Stations per State')

# %%
fig3 = fig3.get_figure()
fig3.savefig('Plots and Maps\Incentives V Charging Stations')

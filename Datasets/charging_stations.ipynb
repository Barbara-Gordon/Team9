# %%
import csv
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
charging_stations_df = pd.read_csv("charging_stations.csv")
charging_stations_df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Fuel Type Code                         Station Name       Street Address  \
# 0           ELEC        Los Angeles Convention Center   1201 S Figueroa St
# 1           ELEC        LADWP - John Ferraro Building        111 N Hope St
# 2           ELEC  Cherokee & Hollywood Parking Garage  1718 N Cherokee Ave
# 3           ELEC                      CITYOFSANTAROSA   100 Santa Rosa Ave
# 4           ELEC       California Air Resources Board     9530 Telstar Ave
#
#                              Intersection Directions         City State  \
# 0                                          West hall  Los Angeles    CA
# 1                                        Across Hope  Los Angeles    CA
# ...

# %%
charging_stations_df = charging_stations_df[charging_stations_df['Fuel Type Code'] == "ELEC"]

# %%
charging_stations_df = charging_stations_df.groupby(['City', 'State', 'ZIP'], as_index=False).agg({'Latitude': 'mean',
                                                 'Longitude': 'mean', 'Station Name': 'count'})
charging_stations_df.head()
# Out:
#                City State      ZIP   Latitude  Longitude  Station Name
# 0          Montréal    QC  H2M 1R6  45.546308 -73.638607             1
# 1          Montréal    QC  H2P 2T2  45.540921 -73.640621             1
# 2          Montréal    QC  H3A 1Y1  45.502857 -73.576811             1
# 3   Saint-Hyacinthe    QC  J2S 4Z6  45.635960 -72.968130             1
# 4     100 fifth Ave    MA    02451  42.393662 -71.255855             1

# %%
col_pal = [ '#456990', "#B8336A", "#F7B538", "#68603A", "#A0855B", "#0A9CC3", "#C7DB67", 
           "#7A6887", "#0F2217", "#D90429", "#83C29E", "#3DFAFF"]
sns.set_palette(sns.color_palette(col_pal))
